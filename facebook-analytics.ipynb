# %% [markdown]
# #Facebook Posts Analytics
# ---
# There I have analyzed how many posts I have made through last 6 months with using of Pandas, Matplotlib, and Seaborn

# %%
import pandas as pd
df = pd.read_json('your_posts_1.json')
df.head(3)
# Out:
#             timestamp                                               data  \
# 0 2021-04-25 16:28:03  [{'post': 'For very low price this guy offers ...
# 1 2021-08-25 06:14:33                 [{'update_timestamp': 1629872073}]
#
#                                                title  \
# 0  Murad Rajabov  ÑÐµÐºÐ¾Ð¼ÐµÐ½Ð´ÑÐµÑ RIGA 5â...
# 1                                                NaN
#
#                                          attachments
# 0                                                NaN
# 1  [{'data': [{'external_context': {'url': 'https...

# %%
df.rename(columns={'timestamp' : 'date'}, inplace= True)
df = df.drop(['attachments', 'title'], axis=1)
pd.to_datetime(df['date'])
df.head(3)
# Out:
#                  date                                               data
# 0 2021-04-25 16:28:03  [{'post': 'For very low price this guy offers ...
# 1 2021-08-25 06:14:33                 [{'update_timestamp': 1629872073}]

# %%
df = df.set_index('date')
post_num = df['data'].resample('MS').size()
post_num
# Out:
# date
# 2021-04-01    1
# 2021-05-01    0
# 2021-06-01    0
# 2021-07-01    0
# 2021-08-01    1
# Freq: MS, Name: data, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# set figure size and font size
sns.set(rc={'figure.figsize':(40,20)})
sns.set(font_scale=3)

# set x labels
x_labels = post_counts.index

#create bar plot
sns.barplot(x_labels, post_counts, color="blue")

# only show x-axis labels for Jan 1 of every other year
tick_positions = np.arange(10, len(x_labels), step=24)

#reformat date to display year onlyplt.ylabel("post counts")
plt.xticks(tick_positions, x_labels[tick_positions].strftime("%Y"))

# display the plot
plt.show()
# Out:
# c:\users\мурад\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
